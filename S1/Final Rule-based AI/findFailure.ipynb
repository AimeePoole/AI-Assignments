# %%
import csv

#------------------------------------------------------------
# turns actual education to a group
#------------------------------------------------------------
def edu_to_category(edu):
    #Less than a high school education
    if edu in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th", "Less-HS"]:
        return "Less-HS"
    
    
    #Highschool grads and more but all before a bachelors
    if edu in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "HS-grad+"
    
    #Bachelors and more
    if edu in ["Bachelors", "Masters", "Doctorate", "Prof-school"]:
        return "Bachelors+"

    return "Other"

#------------------------------------------------------------
# Estimate Education
#------------------------------------------------------------
def estimate_education(age, workclass, occupation, hours_per_week, income, capital_gain, capital_loss):
    
    # Rule 1: If someone is under 18 it is unlikely they have graduated highschool
    #This correctly guesses 1.18% (384/32561) of the data (11 are incorrect) (this is when used on their own)
    if age < 18:
        return "Less-HS"

    #Rule 2: high income and occupations like Exec-managerial and Prof-specialty Bachelors+
    #This correctly guesses 8.65% (2818/32561) (1009 are incorrect)
    if income == ">50K" and occupation in ["Exec-managerial"]:
        return "Bachelors"

    # Rule 3: high hours but not in the high occupations high school or some college
    # This correctly guesses 3.80% (1238/32561) (512 are incorrect)
    if hours_per_week > 55 and occupation not in ["Exec-managerial", "Prof-specialty"]:
        return "HS-grad"
    

    # Rule 4: working low hours for a low wage at a low edu. required occupation 
    # 3.33% (1085/32561 correct)  (Incorrect 633)
    if hours_per_week < 35 and income == "<=50K" and occupation in ["Handlers-cleaners", "Other-service", "Farming-fishing", "Priv-house-serv"]:
        return "HS-grad"

    # Rule 5: High hours, private and a mid-level job Some-college
    # 3.89% (1267/32561 correct) Incorrect: 506
    if hours_per_week > 45 and workclass == "Private" and occupation in [
        "Craft-repair", "Transport-moving", "Sales"
    ]:
        return "HS-grad"
    
    # Rule 6: people who work as in Prof-specialty are more likely to have a degree or more
    if occupation == "Prof-specialty":
        return "Bachelors"
    
    # Rule 7: if older and low-earning likely a high school grad
    # 8.55% (2785/32561 correct) Incorrect: 1692
    if age >= 40 and income == "<=50K":
        return "HS-grad"

    # Rule 8: working full-time as an older adult is likely to be a high school graduate
    #34.29% (11164/32561) Incorrect: 7492 (this should be accounted for by the rules above)
    if hours_per_week >= 40 and age >= 30:
        return  "HS-grad"
    
    # Rule 9: having capital_gain or capital_loss suggests high school education 
    if capital_gain > 0 or capital_loss > 0:
        # people working in these occupations with capital_gain or capital_loss are likely to have a degree
        if occupation in ["Exec-managerial"]:
            return "Bachelors"
        return "HS-grad"

    # Rule 10: people who work in these occupations are more likely to have less than a high school education
    if occupation == "Priv-house-serv":
        return "Less-HS"
    
    # Fallback 
    return "no"


# without fallback Accuracy: Accuracy: 53.83% (17527/32561 correct)
# with fallback HS-grad Accuracy: 67.26% (21900/32561 correct) 
    # (accuracy after removing row with ? Accuracy: 67.55% (20375/30162 correct))
# with fallback Bachelors Accuracy: Accuracy: 56.22% (18305/32561 correct)



correct = 0
total = 0
incorrect_predictions = []
#------------------------------------------------------------
# Test database
#------------------------------------------------------------
with open('adult.data', 'r') as file:
    reader = csv.reader(file)
    import operator

    # Iterate through rows
    for row in reader:

        # Skip rows with fewer than 15 columns (otherwise it wont let me read from file)
        if len(row) < 15:
            continue

        # if fields have ?s
        if not any("?" in cell for cell in row):

            # Convert to int https://www.geeksforgeeks.org/python/convert-string-to-integer-in-python/
            # Only used variables that were relevent to the Rule-based AI          
            age = int(row[0].strip())
            workclass = row[1].strip()
            occupation = row[6].strip()
            hours_per_week = int(row[12].strip())
            income = row[14].strip()
            capital_gain = int(row[10].strip())
            capital_loss = int(row[11].strip())

            edu_num = int(row[4].strip())
            actual_education = row[3].strip()


            predicted = estimate_education(age, workclass, occupation, hours_per_week,income, capital_gain, capital_loss)
            
            if edu_to_category(actual_education) == edu_to_category("Bachelors"):
            #add the rule to the if statement to find the incorrect guesses 
                if edu_to_category(predicted) != edu_to_category(actual_education) and edu_to_category(predicted) == edu_to_category("Less-HS"):
                    
                    incorrect_predictions.append({
                        "age": age, "workclass": workclass, "occupation": occupation, "hours_per_week": hours_per_week, "income": income, "capital_gain": capital_gain, "capital_loss": capital_loss, "edu_level": edu_num, "predicted": predicted, "actual": actual_education
                    })
                else:
                    correct += 1
                
                total += 1

#------------------------------------------------------------
#Calculate accuracy and sort incorrect results (for checking for comment mistakes)
#------------------------------------------------------------
accuracy = correct / total * 100

incorrect_predictions = sorted(
    incorrect_predictions,
    key=lambda x: x["edu_level"],
    reverse=True
)

#accuracy to 2dp (:.2f)
#this shows the precentage correct as well as the fraction
print(f"Accuracy: {accuracy:.2f}% ({correct}/{total} correct)")


for item in incorrect_predictions:
    print(
        f"{item['age']}\t"
        f"{item['workclass']}\t"
        f"{item['occupation']}\t"
        f"{item['hours_per_week']}\t"
        f"{item['income']}\t"
        f"{item['capital_gain']}\t"
        f"{item['capital_loss']}\t"
        f"{item['edu_level']}\t"
        f" Predicted: {item['predicted']}\t"
        f" Actual: {item['actual']}"
    )


print(f"Total Incorrect: {len(incorrect_predictions)}")
# Out:
# Accuracy: 67.80% (5145/7588 correct)
# 44	Private	Adm-clerical	55	>50K	0	0	16	 Predicted: HS-grad	 Actual: Doctorate
# 32	Self-emp-not-inc	Exec-managerial	40	<=50K	0	0	16	 Predicted: HS-grad	 Actual: Doctorate
# 53	State-gov	Adm-clerical	50	>50K	0	0	16	 Predicted: HS-grad	 Actual: Doctorate
# 41	Private	Sales	50	>50K	0	0	16	 Predicted: HS-grad	 Actual: Doctorate
# 33	Private	Sales	60	>50K	99999	0	16	 Predicted: HS-grad	 Actual: Doctorate
# 51	Private	Craft-repair	60	>50K	4787	0	16	 Predicted: HS-grad	 Actual: Doctorate
# 47	Self-emp-not-inc	Craft-repair	50	<=50K	0	0	16	 Predicted: HS-grad	 Actual: Doctorate
# 72	Local-gov	Exec-managerial	40	<=50K	0	1258	16	 Predicted: HS-grad	 Actual: Doctorate
# 67	Self-emp-not-inc	Sales	40	>50K	20051	0	16	 Predicted: HS-grad	 Actual: Doctorate
# 50	Self-emp-not-inc	Sales	64	<=50K	0	0	16	 Predicted: HS-grad	 Actual: Doctorate
# 59	Private	Sales	40	<=50K	0	0	16	 Predicted: HS-grad	 Actual: Doctorate
# 45	Private	Exec-managerial	60	<=50K	0	0	16	 Predicted: HS-grad	 Actual: Doctorate
# 55	Self-emp-not-inc	Exec-managerial	30	<=50K	0	0	16	 Predicted: HS-grad	 Actual: Doctorate
# 61	Local-gov	Exec-managerial	40	<=50K	4064	0	16	 Predicted: HS-grad	 Actual: Doctorate
# 77	Self-emp-inc	Farming-fishing	40	>50K	20051	0	16	 Predicted: HS-grad	 Actual: Doctorate
# 66	Self-emp-not-inc	Sales	25	>50K	0	2377	16	 Predicted: HS-grad	 Actual: Doctorate
# 57	Private	Tech-support	40	>50K	0	1977	16	 Predicted: HS-grad	 Actual: Doctorate
# 47	Self-emp-not-inc	Transport-moving	45	<=50K	0	2002	16	 Predicted: HS-grad	 Actual: Doctorate
# 57	Self-emp-not-inc	Sales	40	>50K	0	1902	16	 Predicted: HS-grad	 Actual: Doctorate
# 49	Private	Sales	60	<=50K	0	0	16	 Predicted: HS-grad	 Actual: Doctorate
# 41	Private	Machine-op-inspct	40	>50K	0	0	16	 Predicted: HS-grad	 Actual: Doctorate
# 42	Self-emp-not-inc	Farming-fishing	65	>50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 52	Self-emp-inc	Exec-managerial	40	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 59	Self-emp-not-inc	Sales	25	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 74	Private	Adm-clerical	20	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 56	Private	Exec-managerial	16	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 57	Private	Craft-repair	40	>50K	0	1902	15	 Predicted: HS-grad	 Actual: Prof-school
# 57	Self-emp-inc	Transport-moving	50	>50K	15024	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 48	Private	Tech-support	40	>50K	0	1977	15	 Predicted: HS-grad	 Actual: Prof-school
# 57	Self-emp-not-inc	Sales	35	>50K	15024	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 40	Private	Craft-repair	40	>50K	5178	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 46	Local-gov	Protective-serv	40	>50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 71	Self-emp-not-inc	Farming-fishing	2	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 43	Private	Tech-support	50	>50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 47	Private	Adm-clerical	40	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 37	Private	Exec-managerial	40	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 32	Private	Sales	60	>50K	15024	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 30	Private	Sales	55	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 34	Private	Tech-support	40	>50K	0	1564	15	 Predicted: HS-grad	 Actual: Prof-school
# 40	Private	Exec-managerial	40	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 41	Private	Sales	50	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 39	Private	Exec-managerial	50	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 59	Self-emp-not-inc	Farming-fishing	30	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 49	State-gov	Exec-managerial	40	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 37	Private	Sales	45	>50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 42	Private	Sales	40	>50K	15024	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 39	Private	Craft-repair	40	>50K	7688	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 52	Self-emp-inc	Sales	40	>50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 48	Self-emp-not-inc	Craft-repair	60	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 61	Private	Exec-managerial	20	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 88	Self-emp-not-inc	Exec-managerial	40	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 56	Local-gov	Adm-clerical	40	>50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 62	Private	Craft-repair	45	>50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 50	Self-emp-not-inc	Sales	50	>50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 39	Private	Sales	99	>50K	0	2415	15	 Predicted: HS-grad	 Actual: Prof-school
# 36	Self-emp-not-inc	Craft-repair	60	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 47	Self-emp-inc	Other-service	60	>50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 50	Local-gov	Adm-clerical	40	>50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 71	State-gov	Other-service	28	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 77	Private	Exec-managerial	40	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 60	Self-emp-not-inc	Sales	45	>50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 46	Private	Farming-fishing	48	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 59	Private	Transport-moving	50	>50K	15024	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 43	Private	Exec-managerial	40	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 34	Private	Exec-managerial	50	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 47	Private	Sales	45	>50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 32	Private	Sales	50	>50K	13550	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 48	Private	Sales	13	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 64	Private	Exec-managerial	60	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 45	Self-emp-inc	Craft-repair	50	>50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 31	Private	Tech-support	40	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 38	Private	Sales	40	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 31	Private	Tech-support	55	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 40	Private	Adm-clerical	40	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 41	Private	Adm-clerical	40	<=50K	0	0	15	 Predicted: HS-grad	 Actual: Prof-school
# 40	Self-emp-not-inc	Other-service	35	<=50K	0	2339	15	 Predicted: HS-grad	 Actual: Prof-school
# 37	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 44	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 44	Self-emp-inc	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 45	Self-emp-not-inc	Sales	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 46	State-gov	Protective-serv	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 50	Self-emp-not-inc	Farming-fishing	98	<=50K	2407	0	14	 Predicted: HS-grad	 Actual: Masters
# 57	Federal-gov	Sales	40	>50K	15024	0	14	 Predicted: HS-grad	 Actual: Masters
# 76	Self-emp-not-inc	Craft-repair	10	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 46	Self-emp-not-inc	Exec-managerial	30	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 43	Self-emp-inc	Exec-managerial	45	<=50K	5013	0	14	 Predicted: HS-grad	 Actual: Masters
# 47	Private	Exec-managerial	42	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 51	Private	Craft-repair	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 35	Private	Sales	60	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 41	Private	Exec-managerial	35	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 31	Private	Tech-support	40	>50K	0	1902	14	 Predicted: HS-grad	 Actual: Masters
# 71	Self-emp-not-inc	Sales	40	>50K	10605	0	14	 Predicted: HS-grad	 Actual: Masters
# 48	Self-emp-inc	Sales	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 35	Self-emp-inc	Sales	45	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 25	Private	Farming-fishing	99	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 61	Self-emp-inc	Sales	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 43	Private	Other-service	30	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 65	Private	Sales	40	>50K	20051	0	14	 Predicted: HS-grad	 Actual: Masters
# 54	Self-emp-not-inc	Sales	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 49	Private	Exec-managerial	75	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 43	Private	Exec-managerial	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 45	Private	Adm-clerical	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 58	Private	Sales	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 38	Private	Craft-repair	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 57	Self-emp-inc	Sales	65	>50K	15024	0	14	 Predicted: HS-grad	 Actual: Masters
# 63	Self-emp-inc	Sales	68	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 58	Self-emp-not-inc	Sales	18	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 29	Private	Sales	40	>50K	7298	0	14	 Predicted: HS-grad	 Actual: Masters
# 50	Federal-gov	Tech-support	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 43	Private	Exec-managerial	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 43	Federal-gov	Protective-serv	60	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 47	Private	Sales	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 30	Local-gov	Adm-clerical	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 44	Private	Exec-managerial	48	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 61	Private	Sales	60	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 43	Self-emp-not-inc	Sales	60	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 54	Private	Sales	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 46	State-gov	Exec-managerial	38	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 36	Private	Sales	50	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 56	Private	Craft-repair	44	>50K	0	1977	14	 Predicted: HS-grad	 Actual: Masters
# 37	Private	Exec-managerial	45	<=50K	0	213	14	 Predicted: HS-grad	 Actual: Masters
# 56	Private	Adm-clerical	80	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 49	Private	Sales	35	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 48	Private	Sales	35	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 35	Self-emp-not-inc	Sales	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 42	Private	Sales	50	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 40	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 40	Federal-gov	Tech-support	40	>50K	0	1902	14	 Predicted: HS-grad	 Actual: Masters
# 46	Self-emp-not-inc	Craft-repair	50	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 39	Private	Transport-moving	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 60	Self-emp-not-inc	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 42	Federal-gov	Adm-clerical	60	<=50K	0	2001	14	 Predicted: HS-grad	 Actual: Masters
# 62	Self-emp-inc	Sales	45	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 53	Federal-gov	Adm-clerical	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 35	Private	Craft-repair	50	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 37	Private	Tech-support	60	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 45	State-gov	Protective-serv	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 35	Private	Adm-clerical	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 49	Private	Adm-clerical	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 53	Private	Sales	60	>50K	7298	0	14	 Predicted: HS-grad	 Actual: Masters
# 45	Private	Transport-moving	48	>50K	14344	0	14	 Predicted: HS-grad	 Actual: Masters
# 46	Private	Tech-support	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 35	Private	Sales	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 66	Private	Sales	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 36	Self-emp-not-inc	Sales	45	>50K	10520	0	14	 Predicted: HS-grad	 Actual: Masters
# 36	Private	Sales	45	>50K	15024	0	14	 Predicted: HS-grad	 Actual: Masters
# 33	Self-emp-inc	Craft-repair	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 37	Self-emp-not-inc	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 41	Private	Adm-clerical	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 54	Self-emp-not-inc	Sales	60	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 39	Private	Sales	50	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 39	Private	Craft-repair	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 45	Self-emp-inc	Sales	42	>50K	25236	0	14	 Predicted: HS-grad	 Actual: Masters
# 39	Private	Exec-managerial	45	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 52	State-gov	Adm-clerical	70	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 57	Private	Adm-clerical	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 39	Private	Exec-managerial	40	<=50K	0	1974	14	 Predicted: HS-grad	 Actual: Masters
# 67	Private	Other-service	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 35	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 30	Private	Adm-clerical	40	>50K	4386	0	14	 Predicted: HS-grad	 Actual: Masters
# 56	Self-emp-not-inc	Craft-repair	50	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 33	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 47	Private	Sales	6	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 67	Self-emp-inc	Sales	48	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 33	State-gov	Protective-serv	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 54	Local-gov	Adm-clerical	40	>50K	7298	0	14	 Predicted: HS-grad	 Actual: Masters
# 49	Local-gov	Protective-serv	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 51	Private	Tech-support	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 35	Private	Sales	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 49	Federal-gov	Adm-clerical	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 55	Private	Sales	50	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 37	Private	Exec-managerial	65	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 40	Local-gov	Adm-clerical	35	<=50K	0	1876	14	 Predicted: HS-grad	 Actual: Masters
# 53	Private	Sales	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 44	Self-emp-not-inc	Farming-fishing	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 48	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 43	Private	Exec-managerial	25	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 54	Self-emp-not-inc	Sales	45	>50K	4386	0	14	 Predicted: HS-grad	 Actual: Masters
# 55	Self-emp-inc	Sales	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 35	Private	Machine-op-inspct	48	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 40	Self-emp-inc	Sales	70	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 48	Self-emp-not-inc	Sales	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 44	Private	Sales	48	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 43	Private	Other-service	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 43	Local-gov	Tech-support	47	>50K	8614	0	14	 Predicted: HS-grad	 Actual: Masters
# 78	Private	Craft-repair	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 45	State-gov	Adm-clerical	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 32	Private	Sales	45	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 39	Private	Sales	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 41	Local-gov	Exec-managerial	55	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 36	Private	Other-service	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 40	State-gov	Exec-managerial	35	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 41	Self-emp-not-inc	Handlers-cleaners	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 44	Self-emp-not-inc	Farming-fishing	99	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 52	Federal-gov	Exec-managerial	40	<=50K	5013	0	14	 Predicted: HS-grad	 Actual: Masters
# 51	Private	Protective-serv	40	>50K	0	1977	14	 Predicted: HS-grad	 Actual: Masters
# 48	Private	Transport-moving	55	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 55	Private	Tech-support	20	>50K	0	1977	14	 Predicted: HS-grad	 Actual: Masters
# 34	Private	Craft-repair	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 25	Private	Sales	55	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 46	Private	Tech-support	40	>50K	0	1977	14	 Predicted: HS-grad	 Actual: Masters
# 39	Self-emp-inc	Exec-managerial	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 45	Federal-gov	Sales	50	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 49	Local-gov	Adm-clerical	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 41	State-gov	Adm-clerical	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 41	Private	Machine-op-inspct	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 37	Federal-gov	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 39	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 34	Private	Exec-managerial	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 45	Private	Adm-clerical	45	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 37	Local-gov	Protective-serv	50	>50K	7688	0	14	 Predicted: HS-grad	 Actual: Masters
# 35	Local-gov	Adm-clerical	41	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 52	Self-emp-not-inc	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 42	Private	Adm-clerical	25	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 45	State-gov	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 47	Private	Adm-clerical	38	>50K	7688	0	14	 Predicted: HS-grad	 Actual: Masters
# 43	Self-emp-not-inc	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 59	Private	Craft-repair	35	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 41	Self-emp-not-inc	Craft-repair	65	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 34	Federal-gov	Adm-clerical	50	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 51	Private	Sales	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 39	Private	Adm-clerical	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 37	Local-gov	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 47	Private	Sales	60	>50K	27828	0	14	 Predicted: HS-grad	 Actual: Masters
# 46	Private	Sales	65	>50K	0	2415	14	 Predicted: HS-grad	 Actual: Masters
# 50	Private	Sales	40	>50K	15024	0	14	 Predicted: HS-grad	 Actual: Masters
# 55	Self-emp-inc	Exec-managerial	60	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 46	Self-emp-not-inc	Exec-managerial	25	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 44	Private	Craft-repair	45	>50K	15024	0	14	 Predicted: HS-grad	 Actual: Masters
# 49	Self-emp-inc	Sales	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 40	Self-emp-inc	Craft-repair	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 56	Private	Sales	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 36	Private	Tech-support	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 44	Private	Sales	24	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 67	Local-gov	Adm-clerical	40	<=50K	2009	0	14	 Predicted: HS-grad	 Actual: Masters
# 50	Private	Exec-managerial	35	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 58	Self-emp-not-inc	Other-service	15	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 48	Self-emp-inc	Other-service	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 39	Self-emp-not-inc	Craft-repair	55	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 31	Private	Sales	76	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 46	Local-gov	Exec-managerial	35	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 50	Self-emp-inc	Sales	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 45	Private	Sales	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 62	Federal-gov	Adm-clerical	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 56	Self-emp-not-inc	Sales	60	<=50K	0	1876	14	 Predicted: HS-grad	 Actual: Masters
# 33	Federal-gov	Transport-moving	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 47	Self-emp-not-inc	Exec-managerial	25	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 58	Private	Adm-clerical	45	<=50K	0	1980	14	 Predicted: HS-grad	 Actual: Masters
# 59	Private	Sales	55	>50K	7298	0	14	 Predicted: HS-grad	 Actual: Masters
# 71	Private	Other-service	20	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 42	Private	Sales	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 39	Private	Sales	50	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 32	Private	Adm-clerical	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 66	Private	Sales	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 57	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 44	Self-emp-not-inc	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 51	Private	Sales	50	>50K	15024	0	14	 Predicted: HS-grad	 Actual: Masters
# 61	Private	Sales	50	<=50K	3103	0	14	 Predicted: HS-grad	 Actual: Masters
# 44	Private	Adm-clerical	50	<=50K	3908	0	14	 Predicted: HS-grad	 Actual: Masters
# 34	Private	Exec-managerial	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 36	Private	Adm-clerical	50	>50K	13550	0	14	 Predicted: HS-grad	 Actual: Masters
# 32	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 44	State-gov	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 40	Self-emp-not-inc	Sales	50	<=50K	3103	0	14	 Predicted: HS-grad	 Actual: Masters
# 34	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 54	Private	Sales	68	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 42	Private	Exec-managerial	40	<=50K	4650	0	14	 Predicted: HS-grad	 Actual: Masters
# 42	Self-emp-inc	Farming-fishing	60	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 46	Private	Exec-managerial	45	<=50K	0	323	14	 Predicted: HS-grad	 Actual: Masters
# 45	Private	Exec-managerial	40	<=50K	4386	0	14	 Predicted: HS-grad	 Actual: Masters
# 49	Private	Sales	50	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 52	Private	Tech-support	45	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 39	Private	Sales	45	>50K	0	2444	14	 Predicted: HS-grad	 Actual: Masters
# 46	Self-emp-inc	Sales	60	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 47	Local-gov	Protective-serv	50	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 27	Private	Handlers-cleaners	30	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 39	Local-gov	Exec-managerial	45	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 52	Self-emp-not-inc	Sales	70	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 55	Local-gov	Exec-managerial	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 38	Private	Adm-clerical	50	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 40	Private	Sales	50	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 38	Self-emp-not-inc	Farming-fishing	70	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 52	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 37	Self-emp-inc	Exec-managerial	70	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 52	Self-emp-inc	Exec-managerial	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 90	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 48	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 58	Self-emp-not-inc	Exec-managerial	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 37	Private	Sales	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 33	Private	Adm-clerical	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 38	Private	Adm-clerical	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 24	Private	Adm-clerical	56	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 54	Private	Adm-clerical	38	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 40	Private	Adm-clerical	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 34	Self-emp-not-inc	Farming-fishing	60	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 50	Self-emp-not-inc	Sales	55	>50K	7688	0	14	 Predicted: HS-grad	 Actual: Masters
# 34	Private	Sales	60	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 61	Self-emp-inc	Exec-managerial	99	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 59	Federal-gov	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 35	Private	Sales	55	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 48	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 63	Self-emp-not-inc	Farming-fishing	50	<=50K	41310	0	14	 Predicted: HS-grad	 Actual: Masters
# 37	Private	Adm-clerical	50	>50K	7688	0	14	 Predicted: HS-grad	 Actual: Masters
# 49	State-gov	Sales	80	>50K	99999	0	14	 Predicted: HS-grad	 Actual: Masters
# 65	Private	Sales	28	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 68	Private	Adm-clerical	20	<=50K	6360	0	14	 Predicted: HS-grad	 Actual: Masters
# 59	Private	Sales	45	>50K	27828	0	14	 Predicted: HS-grad	 Actual: Masters
# 42	Private	Adm-clerical	40	>50K	0	1902	14	 Predicted: HS-grad	 Actual: Masters
# 50	Private	Exec-managerial	40	<=50K	0	1485	14	 Predicted: HS-grad	 Actual: Masters
# 36	Self-emp-not-inc	Farming-fishing	70	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 51	Self-emp-inc	Sales	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 62	Self-emp-inc	Sales	35	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 50	Private	Sales	45	<=50K	0	1590	14	 Predicted: HS-grad	 Actual: Masters
# 53	Self-emp-inc	Sales	65	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 42	Private	Tech-support	35	>50K	4687	0	14	 Predicted: HS-grad	 Actual: Masters
# 52	Federal-gov	Adm-clerical	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 34	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 40	Self-emp-not-inc	Exec-managerial	20	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 71	Local-gov	Exec-managerial	20	<=50K	2050	0	14	 Predicted: HS-grad	 Actual: Masters
# 43	Private	Adm-clerical	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 57	Private	Tech-support	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 35	Self-emp-inc	Adm-clerical	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 56	Self-emp-not-inc	Sales	60	<=50K	0	2339	14	 Predicted: HS-grad	 Actual: Masters
# 31	Private	Sales	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 50	Private	Craft-repair	45	>50K	0	1902	14	 Predicted: HS-grad	 Actual: Masters
# 40	Federal-gov	Tech-support	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 48	Self-emp-inc	Sales	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 41	Self-emp-not-inc	Sales	35	>50K	0	1902	14	 Predicted: HS-grad	 Actual: Masters
# 59	Self-emp-not-inc	Craft-repair	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 48	Private	Exec-managerial	45	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 50	Private	Sales	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 42	Self-emp-not-inc	Sales	80	>50K	99999	0	14	 Predicted: HS-grad	 Actual: Masters
# 51	Federal-gov	Sales	50	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 34	Private	Sales	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 56	Self-emp-not-inc	Sales	16	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 50	Private	Sales	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 49	Private	Protective-serv	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 55	Self-emp-not-inc	Sales	55	>50K	3103	0	14	 Predicted: HS-grad	 Actual: Masters
# 86	Private	Adm-clerical	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 47	Self-emp-not-inc	Exec-managerial	45	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 50	Self-emp-not-inc	Sales	45	>50K	7688	0	14	 Predicted: HS-grad	 Actual: Masters
# 59	Self-emp-inc	Sales	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 46	Private	Adm-clerical	60	<=50K	0	1740	14	 Predicted: HS-grad	 Actual: Masters
# 32	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 70	Self-emp-not-inc	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 54	Private	Sales	55	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 63	Private	Tech-support	40	<=50K	5013	0	14	 Predicted: HS-grad	 Actual: Masters
# 50	Local-gov	Exec-managerial	70	<=50K	4650	0	14	 Predicted: HS-grad	 Actual: Masters
# 34	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 46	Self-emp-inc	Sales	60	>50K	0	1977	14	 Predicted: HS-grad	 Actual: Masters
# 45	State-gov	Exec-managerial	45	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 57	Local-gov	Other-service	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 48	Private	Tech-support	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 48	State-gov	Protective-serv	72	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 28	Private	Sales	80	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 39	Private	Other-service	32	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 45	Private	Other-service	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 46	Federal-gov	Armed-Forces	40	>50K	0	1887	14	 Predicted: HS-grad	 Actual: Masters
# 54	Private	Transport-moving	60	>50K	7688	0	14	 Predicted: HS-grad	 Actual: Masters
# 45	Self-emp-not-inc	Craft-repair	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 60	Private	Transport-moving	10	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 56	Self-emp-not-inc	Exec-managerial	25	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 42	State-gov	Adm-clerical	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 42	State-gov	Exec-managerial	45	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 57	Self-emp-inc	Sales	40	>50K	99999	0	14	 Predicted: HS-grad	 Actual: Masters
# 36	Private	Adm-clerical	40	>50K	0	1977	14	 Predicted: HS-grad	 Actual: Masters
# 35	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 44	State-gov	Adm-clerical	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 49	Private	Sales	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 52	Private	Sales	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 46	Private	Exec-managerial	45	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 42	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 49	Private	Sales	45	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 40	State-gov	Exec-managerial	40	<=50K	1506	0	14	 Predicted: HS-grad	 Actual: Masters
# 32	Private	Sales	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 62	Private	Handlers-cleaners	40	<=50K	4650	0	14	 Predicted: HS-grad	 Actual: Masters
# 46	Self-emp-inc	Sales	50	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 47	Private	Machine-op-inspct	42	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 57	Self-emp-not-inc	Farming-fishing	20	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 41	Private	Exec-managerial	45	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 30	Private	Adm-clerical	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 56	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 47	Private	Tech-support	40	>50K	27828	0	14	 Predicted: HS-grad	 Actual: Masters
# 49	Private	Sales	45	>50K	4787	0	14	 Predicted: HS-grad	 Actual: Masters
# 43	Private	Exec-managerial	45	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 54	Private	Tech-support	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 36	Private	Sales	50	>50K	7688	0	14	 Predicted: HS-grad	 Actual: Masters
# 54	Private	Other-service	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 41	Self-emp-not-inc	Exec-managerial	55	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 63	Private	Handlers-cleaners	46	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 43	Federal-gov	Craft-repair	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 32	Private	Adm-clerical	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 34	State-gov	Machine-op-inspct	40	>50K	0	1848	14	 Predicted: HS-grad	 Actual: Masters
# 45	Local-gov	Adm-clerical	35	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 38	State-gov	Adm-clerical	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 35	Private	Sales	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 75	Private	Protective-serv	16	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 35	Private	Exec-managerial	55	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 51	Local-gov	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 45	State-gov	Adm-clerical	38	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 50	Self-emp-inc	Sales	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 41	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 74	Private	Sales	10	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 34	Private	Exec-managerial	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 53	Private	Adm-clerical	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 51	Private	Protective-serv	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 47	Private	Tech-support	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 49	Local-gov	Adm-clerical	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 33	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 49	Local-gov	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 31	State-gov	Tech-support	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 44	Private	Adm-clerical	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 30	Private	Tech-support	45	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 56	Federal-gov	Adm-clerical	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 36	Private	Sales	50	>50K	0	1977	14	 Predicted: HS-grad	 Actual: Masters
# 41	Private	Exec-managerial	45	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 56	Private	Exec-managerial	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 43	Private	Exec-managerial	45	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 43	Federal-gov	Handlers-cleaners	12	<=50K	5013	0	14	 Predicted: HS-grad	 Actual: Masters
# 43	Self-emp-not-inc	Other-service	30	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 47	Private	Exec-managerial	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 31	Local-gov	Exec-managerial	45	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 55	Self-emp-not-inc	Sales	50	<=50K	2228	0	14	 Predicted: HS-grad	 Actual: Masters
# 40	Self-emp-inc	Other-service	99	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 29	Private	Sales	50	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 35	Self-emp-not-inc	Sales	40	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 44	Private	Exec-managerial	20	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 50	Self-emp-inc	Sales	55	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 50	Federal-gov	Exec-managerial	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 60	Private	Adm-clerical	50	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 58	Private	Sales	27	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 50	Private	Machine-op-inspct	30	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 59	Private	Tech-support	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 48	Self-emp-not-inc	Sales	50	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 37	Self-emp-not-inc	Exec-managerial	60	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 35	Private	Sales	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 34	Self-emp-inc	Sales	60	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 43	Private	Tech-support	40	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 75	Self-emp-not-inc	Sales	45	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 33	Private	Tech-support	50	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 50	Private	Sales	50	>50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 31	Private	Other-service	30	<=50K	0	0	14	 Predicted: HS-grad	 Actual: Masters
# 39	State-gov	Adm-clerical	40	<=50K	2174	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 50	Self-emp-not-inc	Exec-managerial	13	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 56	Local-gov	Tech-support	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 45	Private	Exec-managerial	40	<=50K	0	1408	13	 Predicted: HS-grad	 Actual: Bachelors
# 30	Private	Sales	40	<=50K	2407	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 31	Private	Sales	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 29	Self-emp-not-inc	Sales	70	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 52	Private	Other-service	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 34	Local-gov	Protective-serv	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 40	Private	Exec-managerial	60	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 30	Private	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 37	Private	Sales	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 33	Private	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 42	Private	Other-service	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 27	Private	Craft-repair	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 41	Self-emp-not-inc	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 41	Local-gov	Craft-repair	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 41	Federal-gov	Tech-support	24	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 36	Private	Other-service	36	>50K	7298	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 38	Private	Sales	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 42	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 29	Local-gov	Protective-serv	56	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 37	Self-emp-inc	Sales	60	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 48	Private	Adm-clerical	40	>50K	7688	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 43	Self-emp-not-inc	Sales	42	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 43	Private	Transport-moving	45	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 27	Private	Craft-repair	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 50	State-gov	Protective-serv	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 46	Private	Craft-repair	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 38	Private	Sales	60	>50K	15024	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 31	Self-emp-inc	Farming-fishing	45	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 28	Private	Transport-moving	55	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 31	Self-emp-not-inc	Tech-support	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 32	Private	Tech-support	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 27	Private	Other-service	20	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 52	Self-emp-inc	Sales	55	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 30	Private	Adm-clerical	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 30	State-gov	Tech-support	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 31	Private	Sales	40	<=50K	0	1380	13	 Predicted: HS-grad	 Actual: Bachelors
# 42	Private	Tech-support	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 51	Private	Sales	55	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 47	Self-emp-not-inc	Sales	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 43	Private	Sales	50	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 40	Private	Sales	55	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 41	Self-emp-inc	Tech-support	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 39	Private	Craft-repair	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 51	Self-emp-not-inc	Sales	40	>50K	0	2415	13	 Predicted: HS-grad	 Actual: Bachelors
# 32	Private	Adm-clerical	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 38	Private	Sales	50	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 35	Self-emp-not-inc	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 31	Private	Sales	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 32	Private	Craft-repair	70	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 46	Private	Sales	40	<=50K	0	1504	13	 Predicted: HS-grad	 Actual: Bachelors
# 58	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 53	Self-emp-not-inc	Sales	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 30	Private	Adm-clerical	40	>50K	7298	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 32	Private	Sales	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 30	Private	Exec-managerial	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 27	Private	Sales	40	<=50K	0	1590	13	 Predicted: HS-grad	 Actual: Bachelors
# 22	Private	Sales	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 44	Self-emp-not-inc	Sales	50	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 45	Self-emp-inc	Machine-op-inspct	60	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 41	Private	Exec-managerial	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 41	Private	Craft-repair	40	>50K	3103	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 33	Private	Sales	45	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 36	Private	Tech-support	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 40	Private	Other-service	37	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 33	Private	Sales	60	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 65	Private	Adm-clerical	20	>50K	10605	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 24	State-gov	Adm-clerical	65	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 44	Private	Other-service	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 38	Private	Sales	42	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 31	Private	Exec-managerial	45	<=50K	4650	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 38	Private	Adm-clerical	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 44	Local-gov	Protective-serv	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 47	Private	Exec-managerial	45	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 51	Local-gov	Adm-clerical	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 46	Private	Sales	40	>50K	0	1977	13	 Predicted: HS-grad	 Actual: Bachelors
# 67	Private	Protective-serv	7	>50K	6514	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 47	Self-emp-not-inc	Sales	50	>50K	15024	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 37	Private	Exec-managerial	45	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 37	Private	Machine-op-inspct	43	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 45	Federal-gov	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 48	Private	Craft-repair	45	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 71	Private	Tech-support	16	<=50K	2329	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 35	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 32	Self-emp-inc	Craft-repair	50	>50K	7688	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 46	Self-emp-inc	Sales	52	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 32	Private	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 23	Private	Sales	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 31	Private	Sales	90	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 45	Self-emp-inc	Farming-fishing	35	>50K	4386	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 35	Private	Sales	65	<=50K	0	1980	13	 Predicted: HS-grad	 Actual: Bachelors
# 44	Private	Other-service	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 59	Private	Adm-clerical	30	<=50K	2885	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 47	Local-gov	Protective-serv	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 38	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 43	Local-gov	Craft-repair	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 29	Private	Sales	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 38	Self-emp-not-inc	Other-service	10	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 37	Private	Sales	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 24	Private	Sales	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 52	Private	Sales	60	>50K	15024	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 38	Private	Sales	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 42	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 35	Private	Sales	45	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 38	Private	Sales	48	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 30	Private	Adm-clerical	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 38	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 47	Self-emp-not-inc	Exec-managerial	60	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 41	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 38	Private	Sales	40	>50K	7298	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 32	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 51	Private	Transport-moving	56	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 43	State-gov	Adm-clerical	50	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 45	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 38	Private	Craft-repair	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 28	Private	Craft-repair	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 42	Self-emp-not-inc	Sales	60	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 42	Private	Tech-support	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 45	Private	Sales	55	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 47	Private	Sales	70	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 35	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 30	Private	Sales	48	<=50K	0	1741	13	 Predicted: HS-grad	 Actual: Bachelors
# 90	Private	Exec-managerial	45	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 35	Private	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 44	Self-emp-not-inc	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 49	Private	Sales	50	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 31	Private	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 37	Private	Sales	55	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 39	Private	Sales	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 31	Private	Exec-managerial	40	<=50K	0	1408	13	 Predicted: HS-grad	 Actual: Bachelors
# 36	Private	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 53	Private	Exec-managerial	70	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 53	Private	Sales	50	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 51	Private	Sales	47	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 33	Self-emp-inc	Sales	50	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 24	Private	Machine-op-inspct	65	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 32	Private	Sales	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 50	Private	Adm-clerical	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 55	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 34	Self-emp-not-inc	Sales	60	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 59	Self-emp-not-inc	Sales	40	>50K	15024	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 36	Private	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 44	Federal-gov	Adm-clerical	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 39	Private	Exec-managerial	48	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 42	Self-emp-not-inc	Farming-fishing	45	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 38	Local-gov	Exec-managerial	40	<=50K	0	1741	13	 Predicted: HS-grad	 Actual: Bachelors
# 27	Private	Craft-repair	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 40	Self-emp-not-inc	Sales	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 31	Private	Adm-clerical	45	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 43	Self-emp-not-inc	Exec-managerial	60	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 45	Private	Sales	40	>50K	0	1902	13	 Predicted: HS-grad	 Actual: Bachelors
# 30	Private	Other-service	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 40	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 41	Private	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 65	Self-emp-inc	Sales	60	>50K	99999	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 33	Private	Farming-fishing	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 34	Private	Exec-managerial	70	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 56	Self-emp-inc	Sales	50	>50K	15024	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 33	Self-emp-not-inc	Sales	45	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 37	Private	Farming-fishing	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# ...
# 36	Private	Exec-managerial	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 23	Private	Tech-support	40	<=50K	3325	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 31	Private	Craft-repair	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 27	Private	Sales	46	>50K	13550	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 23	Private	Sales	55	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 23	Private	Other-service	66	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 35	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 27	Private	Sales	45	>50K	10520	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 51	Private	Sales	50	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 34	Private	Sales	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 52	Local-gov	Tech-support	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 30	Private	Sales	45	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 43	Local-gov	Exec-managerial	42	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 39	Private	Exec-managerial	45	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 25	Self-emp-inc	Sales	80	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 42	Private	Adm-clerical	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 33	Private	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 45	Private	Transport-moving	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 45	Self-emp-not-inc	Transport-moving	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 25	Private	Other-service	24	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 39	Private	Sales	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 37	Private	Sales	60	>50K	99999	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 30	Self-emp-inc	Sales	50	>50K	7688	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 36	Private	Exec-managerial	40	<=50K	0	1741	13	 Predicted: HS-grad	 Actual: Bachelors
# 32	Private	Handlers-cleaners	50	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 30	Private	Sales	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 33	Private	Adm-clerical	45	>50K	0	1902	13	 Predicted: HS-grad	 Actual: Bachelors
# 45	Local-gov	Exec-managerial	60	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 42	Private	Sales	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 36	Private	Sales	45	>50K	0	2415	13	 Predicted: HS-grad	 Actual: Bachelors
# 39	Private	Sales	50	>50K	15024	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 54	Self-emp-not-inc	Craft-repair	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 48	Federal-gov	Adm-clerical	40	>50K	7688	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 31	Private	Other-service	30	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 33	Self-emp-not-inc	Sales	50	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 47	Private	Craft-repair	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 35	Private	Sales	45	>50K	8614	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 62	Self-emp-not-inc	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 43	Self-emp-inc	Sales	45	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 63	Local-gov	Transport-moving	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 35	Private	Exec-managerial	45	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 33	Private	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 44	Private	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 49	Private	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 35	Self-emp-not-inc	Craft-repair	45	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 44	Federal-gov	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 45	Self-emp-not-inc	Farming-fishing	77	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 38	State-gov	Protective-serv	60	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 31	Local-gov	Craft-repair	40	>50K	8614	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 36	Private	Sales	35	>50K	0	1887	13	 Predicted: HS-grad	 Actual: Bachelors
# 59	State-gov	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 57	Federal-gov	Tech-support	48	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 56	Private	Adm-clerical	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 34	Private	Sales	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 64	Private	Sales	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 38	Private	Tech-support	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 34	Private	Sales	45	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 50	Private	Sales	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 39	Self-emp-not-inc	Exec-managerial	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 45	Self-emp-inc	Exec-managerial	60	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 35	Federal-gov	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 38	Private	Sales	44	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 33	Self-emp-not-inc	Other-service	15	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 40	Private	Tech-support	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 30	Private	Adm-clerical	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 43	Private	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 40	Private	Adm-clerical	50	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 43	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 42	Private	Sales	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 46	Self-emp-inc	Exec-managerial	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 47	Private	Adm-clerical	40	>50K	7298	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 38	Self-emp-not-inc	Farming-fishing	60	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 30	Private	Exec-managerial	42	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 45	Private	Sales	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 39	Private	Sales	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 27	Local-gov	Protective-serv	68	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 43	Private	Other-service	35	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 31	Private	Sales	65	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 42	Private	Adm-clerical	40	>50K	0	1887	13	 Predicted: HS-grad	 Actual: Bachelors
# 50	Private	Sales	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 54	Self-emp-not-inc	Farming-fishing	50	>50K	27828	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 36	State-gov	Protective-serv	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 36	Private	Sales	40	<=50K	0	1741	13	 Predicted: HS-grad	 Actual: Bachelors
# 46	Private	Sales	48	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 35	Private	Sales	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 39	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 50	State-gov	Adm-clerical	37	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 55	Private	Adm-clerical	40	<=50K	3464	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 42	Local-gov	Adm-clerical	45	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 22	Private	Farming-fishing	20	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 41	Self-emp-inc	Exec-managerial	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 45	Private	Craft-repair	40	>50K	3103	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 41	Private	Protective-serv	60	>50K	15024	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 43	Private	Sales	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 30	Self-emp-not-inc	Craft-repair	60	<=50K	6849	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 30	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 50	Self-emp-not-inc	Farming-fishing	80	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 30	Private	Adm-clerical	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 47	Private	Sales	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 32	Private	Sales	40	>50K	0	1902	13	 Predicted: HS-grad	 Actual: Bachelors
# 39	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 35	Private	Sales	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 27	Private	Sales	55	>50K	0	1848	13	 Predicted: HS-grad	 Actual: Bachelors
# 53	Private	Other-service	35	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 38	Private	Adm-clerical	50	>50K	5178	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 51	Self-emp-inc	Protective-serv	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 44	Private	Sales	50	>50K	7688	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 31	Private	Adm-clerical	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 49	Self-emp-not-inc	Sales	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 30	Self-emp-not-inc	Sales	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 37	Self-emp-inc	Craft-repair	60	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 33	Local-gov	Exec-managerial	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 24	Private	Tech-support	40	<=50K	3674	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 30	Private	Sales	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 39	Private	Tech-support	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 32	Private	Craft-repair	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 47	Private	Machine-op-inspct	44	>50K	7688	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 70	Private	Handlers-cleaners	40	>50K	6418	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 31	Private	Other-service	25	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 28	Private	Sales	42	>50K	7298	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 34	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 39	Private	Adm-clerical	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 23	Private	Other-service	30	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 48	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 48	State-gov	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 42	Private	Tech-support	50	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 73	Self-emp-not-inc	Farming-fishing	30	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 32	Self-emp-not-inc	Sales	47	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 33	Private	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 45	Private	Adm-clerical	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 52	Private	Exec-managerial	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 36	State-gov	Protective-serv	55	>50K	7298	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 41	Private	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 32	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 25	Private	Tech-support	60	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 48	Self-emp-inc	Farming-fishing	70	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 41	Private	Adm-clerical	35	>50K	3103	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 44	Private	Craft-repair	50	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 26	State-gov	Adm-clerical	80	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 44	Self-emp-inc	Craft-repair	50	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 45	Private	Tech-support	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 36	Private	Handlers-cleaners	30	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 31	Private	Exec-managerial	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 52	Local-gov	Protective-serv	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 51	Self-emp-not-inc	Tech-support	45	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 44	Private	Exec-managerial	45	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 49	Private	Transport-moving	30	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 40	Self-emp-not-inc	Exec-managerial	45	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 39	Private	Tech-support	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 49	Private	Craft-repair	60	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 42	Federal-gov	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 33	Private	Sales	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 50	Private	Sales	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 34	Private	Sales	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 47	Private	Farming-fishing	65	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 50	Private	Sales	35	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 42	Self-emp-not-inc	Exec-managerial	30	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 51	Self-emp-inc	Exec-managerial	25	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 46	Private	Other-service	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 23	Private	Sales	48	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 40	State-gov	Exec-managerial	20	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 45	Self-emp-not-inc	Sales	60	<=50K	2829	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 42	Self-emp-inc	Craft-repair	60	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 56	Federal-gov	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 22	Private	Adm-clerical	30	<=50K	1055	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 23	Private	Sales	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 44	Private	Adm-clerical	45	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 49	Private	Exec-managerial	43	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 37	Private	Sales	45	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 40	Private	Handlers-cleaners	80	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 34	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 32	Self-emp-inc	Craft-repair	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 42	Local-gov	Protective-serv	42	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 38	Private	Sales	40	>50K	7298	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 46	Private	Machine-op-inspct	8	<=50K	0	1602	13	 Predicted: HS-grad	 Actual: Bachelors
# 59	Private	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 36	State-gov	Sales	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 35	Private	Sales	45	>50K	10520	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 44	Self-emp-not-inc	Sales	42	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 43	Local-gov	Protective-serv	55	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 34	Private	Exec-managerial	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 31	Private	Sales	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 45	State-gov	Protective-serv	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 35	Private	Other-service	20	>50K	7688	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 37	Self-emp-not-inc	Sales	50	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 42	Self-emp-not-inc	Farming-fishing	35	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 37	Local-gov	Other-service	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 50	Private	Tech-support	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 34	Private	Craft-repair	40	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 74	Self-emp-not-inc	Craft-repair	8	>50K	15831	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 34	Private	Adm-clerical	45	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 44	Private	Transport-moving	55	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 43	Private	Adm-clerical	40	<=50K	0	1741	13	 Predicted: HS-grad	 Actual: Bachelors
# 42	Private	Sales	40	>50K	7298	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 30	Private	Sales	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 35	Private	Exec-managerial	45	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 39	Federal-gov	Adm-clerical	40	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 36	Self-emp-not-inc	Sales	50	>50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# 85	Private	Exec-managerial	3	<=50K	0	0	13	 Predicted: HS-grad	 Actual: Bachelors
# Total Incorrect: 2443
