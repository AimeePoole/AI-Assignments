# %%
import csv

#------------------------------------------------------------
# turns actual education to a group
#------------------------------------------------------------
def edu_to_category(edu):
    #Less than a high school education
    if edu in ["Preschool", "1st-4th", "5th-6th", "7th-8th", "9th", "10th", "11th", "12th", "Less-HS"]:
        return "Less-HS"
    
    #Highschool grads and more but all before a bachelors
    if edu in ["HS-grad", "Some-college", "Assoc-voc", "Assoc-acdm"]:
        return "HS-grad+"
    
    #Bachelors and more
    if edu in ["Bachelors", "Masters", "Doctorate", "Prof-school"]:
        return "Bachelors+"

    return "Other"

#------------------------------------------------------------
# Estimate Education
#------------------------------------------------------------
def estimate_education(age, workclass, occupation, hours_per_week, income, capital_gain, capital_loss):
    
    # Rule 1: If someone is under 18 it is unlikely they have graduated highschool
    #This correctly guesses 1.18% (384/32561) of the data (11 are incorrect) (this is when used on their own)
    if age < 18:
        return "Less-HS"

    #Rule 2: high income and occupations like Exec-managerial and Prof-specialty Bachelors+
    #This correctly guesses 8.65% (2818/32561) (1009 are incorrect)
    if income == ">50K" and occupation in ["Exec-managerial"]:
        return "Bachelors"

    # Rule 3: high hours but not in the high occupations high school or some college
    # This correctly guesses 3.80% (1238/32561) (512 are incorrect)
    if hours_per_week > 55 and occupation not in ["Exec-managerial", "Prof-specialty"]:
        return "HS-grad"
    

    # Rule 4: working low hours for a low wage at a low edu. required occupation 
    # 3.33% (1085/32561 correct)  (Incorrect 633)
    if hours_per_week < 35 and income == "<=50K" and occupation in ["Handlers-cleaners", "Other-service", "Farming-fishing", "Priv-house-serv"]:
        return "HS-grad"

    # Rule 5: High hours, private and a mid-level job Some-college
    # 3.89% (1267/32561 correct) Incorrect: 506
    if hours_per_week > 45 and workclass == "Private" and occupation in [
        "Craft-repair", "Transport-moving", "Sales"
    ]:
        return "HS-grad"
    
    # Rule 6: people who work as in Prof-specialty are more likely to have a degree or more
    if occupation == "Prof-specialty":
        return "Bachelors"
    
    # Rule 7: if older and low-earning likely a high school grad
    # 8.55% (2785/32561 correct) Incorrect: 1692
    if age >= 40 and income == "<=50K":
        return "HS-grad"

    # Rule 8: working full-time as an older adult is likely to be a high school graduate
    #34.29% (11164/32561) Incorrect: 7492 (this should be accounted for by the rules above)
    if hours_per_week >= 40 and age >= 30:
        return  "HS-grad"
    
    # Rule 9: having capital_gain or capital_loss suggests high school education 
    if capital_gain > 0 or capital_loss > 0:
        # people working in these occupations with capital_gain or capital_loss are likely to have a degree
        if occupation in ["Exec-managerial"]:
            return "Bachelors"
        return "HS-grad"

    # Rule 10: people who work in these occupations are more likely to have less than a high school education
    if occupation == "Priv-house-serv":
        return "Less-HS"
    
    # Fallback 
    return "HS-grad"


# without fallback Accuracy: Accuracy: 53.83% (17527/32561 correct)
# with fallback HS-grad Accuracy: 67.26% (21900/32561 correct) 
    # (accuracy after removing row with ? Accuracy: 67.55% (20375/30162 correct))
# with fallback Bachelors Accuracy: Accuracy: 56.22% (18305/32561 correct)



correct = 0
total = 0
incorrect_predictions = []
#------------------------------------------------------------
# Test database
#------------------------------------------------------------
with open('adult.data', 'r') as file:
    reader = csv.reader(file)
    import operator

    # Iterate through rows
    for row in reader:

        # Skip rows with fewer than 15 columns (otherwise it wont let me read from file)
        if len(row) < 15:
            continue

        # if fields have ?s
        if not any("?" in cell for cell in row):

            # Convert to int https://www.geeksforgeeks.org/python/convert-string-to-integer-in-python/
            # Only used variables that were relevent to the Rule-based AI          
            age = int(row[0].strip())
            workclass = row[1].strip()
            occupation = row[6].strip()
            hours_per_week = int(row[12].strip())
            income = row[14].strip()
            capital_gain = int(row[10].strip())
            capital_loss = int(row[11].strip())

            edu_num = int(row[4].strip())
            actual_education = row[3].strip()


            predicted = estimate_education(age, workclass, occupation, hours_per_week,income, capital_gain, capital_loss)
            #add the rule to the if statement to find the incorrect guesses 
            if edu_to_category(predicted) != edu_to_category(actual_education):
                
                incorrect_predictions.append({
                    "age": age, 
                    "workclass": workclass, 
                    "occupation": occupation, 
                    "hours_per_week": hours_per_week, 
                    "income": income, 
                    "capital_gain": capital_gain, 
                    "capital_loss": capital_loss, 
                    "edu_level": edu_num, 
                    "predicted": predicted, 
                    "actual": actual_education
                })
            else:
                correct += 1
            
            total += 1

#------------------------------------------------------------
#Calculate accuracy and sort incorrect results (for checking for comment mistakes)
#------------------------------------------------------------
accuracy = correct / total * 100

incorrect_predictions = sorted(
    incorrect_predictions,
    key=lambda x: x["edu_level"],
    reverse=True
)

#accuracy to 2dp (:.2f)
#this shows the precentage correct as well as the fraction
print(f"Accuracy: {accuracy:.2f}% ({correct}/{total} correct)")


#this will print each value out with gaps but it doesnt have the column title
'''
for item in incorrect_predictions[0:10]:
    print(
        f"{item['age']}\t"
        f"{item['workclass']}\t"
        f"{item['occupation']}\t"
        f"{item['hours_per_week']}\t"
        f"{item['income']}\t"
        f"{item['capital_gain']}\t"
        f"{item['capital_loss']}\t"
        f"{item['edu_level']}\t"
        f"{item['predicted']}\t"
        f"{item['actual']}"
    )
'''
    
for item in incorrect_predictions[:100]:  # limit first 50 to avoid wall of text
    print(item)


print(f"Total Incorrect: {len(incorrect_predictions)}")
# Out:
# Accuracy: 72.03% (21727/30162 correct)
# {'age': 44, 'workclass': 'Private', 'occupation': 'Adm-clerical', 'hours_per_week': 55, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 32, 'workclass': 'Self-emp-not-inc', 'occupation': 'Exec-managerial', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 53, 'workclass': 'State-gov', 'occupation': 'Adm-clerical', 'hours_per_week': 50, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 41, 'workclass': 'Private', 'occupation': 'Sales', 'hours_per_week': 50, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 27, 'workclass': 'Private', 'occupation': 'Adm-clerical', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 33, 'workclass': 'Private', 'occupation': 'Sales', 'hours_per_week': 60, 'income': '>50K', 'capital_gain': 99999, 'capital_loss': 0, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 51, 'workclass': 'Private', 'occupation': 'Craft-repair', 'hours_per_week': 60, 'income': '>50K', 'capital_gain': 4787, 'capital_loss': 0, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 47, 'workclass': 'Self-emp-not-inc', 'occupation': 'Craft-repair', 'hours_per_week': 50, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 72, 'workclass': 'Local-gov', 'occupation': 'Exec-managerial', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 1258, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 67, 'workclass': 'Self-emp-not-inc', 'occupation': 'Sales', 'hours_per_week': 40, 'income': '>50K', 'capital_gain': 20051, 'capital_loss': 0, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 50, 'workclass': 'Self-emp-not-inc', 'occupation': 'Sales', 'hours_per_week': 64, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 59, 'workclass': 'Private', 'occupation': 'Sales', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 45, 'workclass': 'Private', 'occupation': 'Exec-managerial', 'hours_per_week': 60, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 55, 'workclass': 'Self-emp-not-inc', 'occupation': 'Exec-managerial', 'hours_per_week': 30, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 61, 'workclass': 'Local-gov', 'occupation': 'Exec-managerial', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 4064, 'capital_loss': 0, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 28, 'workclass': 'Private', 'occupation': 'Adm-clerical', 'hours_per_week': 18, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 77, 'workclass': 'Self-emp-inc', 'occupation': 'Farming-fishing', 'hours_per_week': 40, 'income': '>50K', 'capital_gain': 20051, 'capital_loss': 0, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 34, 'workclass': 'State-gov', 'occupation': 'Tech-support', 'hours_per_week': 20, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 66, 'workclass': 'Self-emp-not-inc', 'occupation': 'Sales', 'hours_per_week': 25, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 2377, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 57, 'workclass': 'Private', 'occupation': 'Tech-support', 'hours_per_week': 40, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 1977, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 47, 'workclass': 'Self-emp-not-inc', 'occupation': 'Transport-moving', 'hours_per_week': 45, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 2002, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 57, 'workclass': 'Self-emp-not-inc', 'occupation': 'Sales', 'hours_per_week': 40, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 1902, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 49, 'workclass': 'Private', 'occupation': 'Sales', 'hours_per_week': 60, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 41, 'workclass': 'Private', 'occupation': 'Machine-op-inspct', 'hours_per_week': 40, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 16, 'predicted': 'HS-grad', 'actual': 'Doctorate'}
# {'age': 42, 'workclass': 'Self-emp-not-inc', 'occupation': 'Farming-fishing', 'hours_per_week': 65, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 61, 'workclass': 'Private', 'occupation': 'Transport-moving', 'hours_per_week': 5, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 52, 'workclass': 'Self-emp-inc', 'occupation': 'Exec-managerial', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 35, 'workclass': 'Private', 'occupation': 'Sales', 'hours_per_week': 35, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 59, 'workclass': 'Self-emp-not-inc', 'occupation': 'Sales', 'hours_per_week': 25, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 74, 'workclass': 'Private', 'occupation': 'Adm-clerical', 'hours_per_week': 20, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 56, 'workclass': 'Private', 'occupation': 'Exec-managerial', 'hours_per_week': 16, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 57, 'workclass': 'Private', 'occupation': 'Craft-repair', 'hours_per_week': 40, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 1902, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 57, 'workclass': 'Self-emp-inc', 'occupation': 'Transport-moving', 'hours_per_week': 50, 'income': '>50K', 'capital_gain': 15024, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 48, 'workclass': 'Private', 'occupation': 'Tech-support', 'hours_per_week': 40, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 1977, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 57, 'workclass': 'Self-emp-not-inc', 'occupation': 'Sales', 'hours_per_week': 35, 'income': '>50K', 'capital_gain': 15024, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 27, 'workclass': 'Private', 'occupation': 'Adm-clerical', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 40, 'workclass': 'Private', 'occupation': 'Craft-repair', 'hours_per_week': 40, 'income': '>50K', 'capital_gain': 5178, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 46, 'workclass': 'Local-gov', 'occupation': 'Protective-serv', 'hours_per_week': 40, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 71, 'workclass': 'Self-emp-not-inc', 'occupation': 'Farming-fishing', 'hours_per_week': 2, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 43, 'workclass': 'Private', 'occupation': 'Tech-support', 'hours_per_week': 50, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 47, 'workclass': 'Private', 'occupation': 'Adm-clerical', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 37, 'workclass': 'Private', 'occupation': 'Exec-managerial', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 32, 'workclass': 'Private', 'occupation': 'Sales', 'hours_per_week': 60, 'income': '>50K', 'capital_gain': 15024, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 30, 'workclass': 'Private', 'occupation': 'Sales', 'hours_per_week': 55, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 34, 'workclass': 'Private', 'occupation': 'Tech-support', 'hours_per_week': 40, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 1564, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 40, 'workclass': 'Private', 'occupation': 'Exec-managerial', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 41, 'workclass': 'Private', 'occupation': 'Sales', 'hours_per_week': 50, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 36, 'workclass': 'Self-emp-not-inc', 'occupation': 'Sales', 'hours_per_week': 30, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 39, 'workclass': 'Private', 'occupation': 'Exec-managerial', 'hours_per_week': 50, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 59, 'workclass': 'Self-emp-not-inc', 'occupation': 'Farming-fishing', 'hours_per_week': 30, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 49, 'workclass': 'State-gov', 'occupation': 'Exec-managerial', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 37, 'workclass': 'Private', 'occupation': 'Sales', 'hours_per_week': 45, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 42, 'workclass': 'Private', 'occupation': 'Sales', 'hours_per_week': 40, 'income': '>50K', 'capital_gain': 15024, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 39, 'workclass': 'Private', 'occupation': 'Craft-repair', 'hours_per_week': 40, 'income': '>50K', 'capital_gain': 7688, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 52, 'workclass': 'Self-emp-inc', 'occupation': 'Sales', 'hours_per_week': 40, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 48, 'workclass': 'Self-emp-not-inc', 'occupation': 'Craft-repair', 'hours_per_week': 60, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 30, 'workclass': 'Private', 'occupation': 'Other-service', 'hours_per_week': 35, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 61, 'workclass': 'Private', 'occupation': 'Exec-managerial', 'hours_per_week': 20, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 88, 'workclass': 'Self-emp-not-inc', 'occupation': 'Exec-managerial', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 30, 'workclass': 'Private', 'occupation': 'Tech-support', 'hours_per_week': 24, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 56, 'workclass': 'Local-gov', 'occupation': 'Adm-clerical', 'hours_per_week': 40, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 62, 'workclass': 'Private', 'occupation': 'Craft-repair', 'hours_per_week': 45, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 50, 'workclass': 'Self-emp-not-inc', 'occupation': 'Sales', 'hours_per_week': 50, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 39, 'workclass': 'Private', 'occupation': 'Sales', 'hours_per_week': 99, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 2415, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 36, 'workclass': 'Self-emp-not-inc', 'occupation': 'Craft-repair', 'hours_per_week': 60, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 69, 'workclass': 'State-gov', 'occupation': 'Adm-clerical', 'hours_per_week': 34, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 47, 'workclass': 'Self-emp-inc', 'occupation': 'Other-service', 'hours_per_week': 60, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 50, 'workclass': 'Local-gov', 'occupation': 'Adm-clerical', 'hours_per_week': 40, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 71, 'workclass': 'State-gov', 'occupation': 'Other-service', 'hours_per_week': 28, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 77, 'workclass': 'Private', 'occupation': 'Exec-managerial', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 60, 'workclass': 'Self-emp-not-inc', 'occupation': 'Sales', 'hours_per_week': 45, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 46, 'workclass': 'Private', 'occupation': 'Farming-fishing', 'hours_per_week': 48, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 59, 'workclass': 'Private', 'occupation': 'Transport-moving', 'hours_per_week': 50, 'income': '>50K', 'capital_gain': 15024, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 43, 'workclass': 'Private', 'occupation': 'Exec-managerial', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 34, 'workclass': 'Private', 'occupation': 'Exec-managerial', 'hours_per_week': 50, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 47, 'workclass': 'Private', 'occupation': 'Sales', 'hours_per_week': 45, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 32, 'workclass': 'Private', 'occupation': 'Sales', 'hours_per_week': 50, 'income': '>50K', 'capital_gain': 13550, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 48, 'workclass': 'Private', 'occupation': 'Sales', 'hours_per_week': 13, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 31, 'workclass': 'Private', 'occupation': 'Tech-support', 'hours_per_week': 35, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 64, 'workclass': 'Private', 'occupation': 'Exec-managerial', 'hours_per_week': 60, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 45, 'workclass': 'Self-emp-inc', 'occupation': 'Craft-repair', 'hours_per_week': 50, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 31, 'workclass': 'Private', 'occupation': 'Tech-support', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 38, 'workclass': 'Private', 'occupation': 'Sales', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 31, 'workclass': 'Private', 'occupation': 'Tech-support', 'hours_per_week': 55, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 40, 'workclass': 'Private', 'occupation': 'Adm-clerical', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 41, 'workclass': 'Private', 'occupation': 'Adm-clerical', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 40, 'workclass': 'Self-emp-not-inc', 'occupation': 'Other-service', 'hours_per_week': 35, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 2339, 'edu_level': 15, 'predicted': 'HS-grad', 'actual': 'Prof-school'}
# {'age': 37, 'workclass': 'Private', 'occupation': 'Exec-managerial', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 14, 'predicted': 'HS-grad', 'actual': 'Masters'}
# {'age': 44, 'workclass': 'Private', 'occupation': 'Exec-managerial', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 14, 'predicted': 'HS-grad', 'actual': 'Masters'}
# {'age': 44, 'workclass': 'Self-emp-inc', 'occupation': 'Exec-managerial', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 14, 'predicted': 'HS-grad', 'actual': 'Masters'}
# {'age': 45, 'workclass': 'Self-emp-not-inc', 'occupation': 'Sales', 'hours_per_week': 40, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 14, 'predicted': 'HS-grad', 'actual': 'Masters'}
# {'age': 46, 'workclass': 'State-gov', 'occupation': 'Protective-serv', 'hours_per_week': 40, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 14, 'predicted': 'HS-grad', 'actual': 'Masters'}
# {'age': 50, 'workclass': 'Self-emp-not-inc', 'occupation': 'Farming-fishing', 'hours_per_week': 98, 'income': '<=50K', 'capital_gain': 2407, 'capital_loss': 0, 'edu_level': 14, 'predicted': 'HS-grad', 'actual': 'Masters'}
# {'age': 57, 'workclass': 'Federal-gov', 'occupation': 'Sales', 'hours_per_week': 40, 'income': '>50K', 'capital_gain': 15024, 'capital_loss': 0, 'edu_level': 14, 'predicted': 'HS-grad', 'actual': 'Masters'}
# {'age': 76, 'workclass': 'Self-emp-not-inc', 'occupation': 'Craft-repair', 'hours_per_week': 10, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 14, 'predicted': 'HS-grad', 'actual': 'Masters'}
# {'age': 46, 'workclass': 'Self-emp-not-inc', 'occupation': 'Exec-managerial', 'hours_per_week': 30, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 14, 'predicted': 'HS-grad', 'actual': 'Masters'}
# {'age': 43, 'workclass': 'Self-emp-inc', 'occupation': 'Exec-managerial', 'hours_per_week': 45, 'income': '<=50K', 'capital_gain': 5013, 'capital_loss': 0, 'edu_level': 14, 'predicted': 'HS-grad', 'actual': 'Masters'}
# {'age': 47, 'workclass': 'Private', 'occupation': 'Exec-managerial', 'hours_per_week': 42, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 14, 'predicted': 'HS-grad', 'actual': 'Masters'}
# {'age': 51, 'workclass': 'Private', 'occupation': 'Craft-repair', 'hours_per_week': 40, 'income': '>50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 14, 'predicted': 'HS-grad', 'actual': 'Masters'}
# {'age': 35, 'workclass': 'Private', 'occupation': 'Sales', 'hours_per_week': 60, 'income': '<=50K', 'capital_gain': 0, 'capital_loss': 0, 'edu_level': 14, 'predicted': 'HS-grad', 'actual': 'Masters'}
# Total Incorrect: 8435
